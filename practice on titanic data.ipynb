# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 
import numpy as np
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df.shape
# Out:
# (891, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# # insights

# %%
Total passengers: 891
age count = 714 → 177 missing age
More people died than survived   -->Survival rate is low
pasenger class Mean ≈ 2.3 and Median = 3

# %%
df.describe(include='category')
# Out:
#         class deck
# count     891  203
# unique      3    7
# top     Third    C
# freq      491   59

# %%
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
(df.isna().sum()/df.shape[0])*100 #missing percentage of each column
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [182 rows x 15 columns]

# %%
df.dropna().shape[0]
# Out:
# (182, 15)

# %%
df.shape[0] #cal % of loss
# Out:
# (891, 15)

# %%
((891-182)/891)*100
# Out:
# 79.57351290684625

# %%
((df.shape[0]-df.dropna().shape[0])/df.shape[0])*100 # % of loss -->no recommended this
# Out:
# 79.57351290684625

# %% [markdown]
# #deck colum as >20% or 77% we can remove this column
# age -np.median
# embark_town mode
# embarked  mode

# %%
age_median=df['age'].median()
age_median
# Out:
# 28.0

# %%
df.drop('deck',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df.drop('deck',axis=1,inplace=True)
#
# File E:\anaconda\new\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File E:\anaconda\new\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File E:\anaconda\new\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File E:\anaconda\new\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['deck'] not found in axis"

# %%
df['age'].fillna(df['age'].median(), inplace=True)
df['embark_town'].fillna(df['embark_town'].mode()[0],inplace=True)
df['embarked'].fillna(df['embarked'].mode()[0],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16936\2504489266.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(),inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_16936\2504489266.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['embark_town'].fillna(df['embark_town'].mode()[0],inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_16936\2504489266.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['embarked'].fillna(df['embarked'].mode()[0],inplace=True)

# %%
df['age'] = df['age'].fillna(df['age'].median())
df['embark_town'] = df['embark_town'].fillna(df['embark_town'].mode()[0])
df['embarked'] = df['embarked'].fillna(df['embarked'].mode()[0])

# %%
df['age'] = df['age'].fillna(df['age'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  891 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# # univeriate Analysis
# numberical
#
#   1.histogram
#
# categorical
#   1.countplot

# %% [markdown]
# # numerical

# %% [markdown]
# #survived
# #pclass
# #age
# #sibsp
# #parch
# fare

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sibsp'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['embark_town'])
plt.show()

# %% [markdown]
# # bivariate analysis
#  use only 2 colums

# %%
#1.histogram age  sex
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sibsp'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sibsp'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.histplot(x=df['pclass'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.histplot(x=df['age'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.histplot(x=df['parch'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.histplot(x=df['fare'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.histplot(x=df['survived'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.histplot(x=df['pclass'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.histplot(x=df['age'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.histplot(x=df['parch'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.histplot(x=df['fare'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.histplot(x=df['survived'],hue=df['deck'],kde=True)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.histplot(x=df['pclass'],hue=df['deck'],kde=True)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['sex'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['class'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['who'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['deck'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['embark_town'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['alive'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['sex'],hue=df['class'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['sex'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['sex'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['sex'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['sex'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['class'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['class'],hue=df['deck'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['class'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['class'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['adult_male'],hue=df['sex'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['adult_male'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['adult_male'],hue=df['class'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['adult_male'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['adult_male'],hue=df['deck'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['adult_male'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['adult_male'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['deck'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['deck'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['embark_town'],hue=df['alive'])
plt.show()
