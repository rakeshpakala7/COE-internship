# %%
import pandas as pd
Uber_data=pd.read_csv("Uber_Drives_2016.csv")
Uber_data.head() #first 5 rows
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
Uber_data.tail()# last 5 rows
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
print(Uber_data.shape)# no of rows and columns
# Out:
# (1156, 7)

# %%
print(Uber_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB
# None

# %%
print(Uber_data.isnull().sum())
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
null_rows=Uber_data[Uber_data.isnull().any(axis=1)]
print(null_rows)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 32      1/19/2016 9:09    1/19/2016 9:23  Business       Whitebridge
# 85      2/9/2016 10:54    2/9/2016 11:07  Personal       Whitebridge
# 86      2/9/2016 11:43    2/9/2016 11:50  Personal        Northwoods
# 87      2/9/2016 13:36    2/9/2016 13:52  Personal        Tanglewood
# ...                ...               ...       ...               ...
# 1066  12/19/2016 14:37  12/19/2016 14:50  Business  Unknown Location
# 1069  12/19/2016 19:05  12/19/2016 19:17  Business         Islamabad
# 1071   12/20/2016 8:49   12/20/2016 9:24  Business  Unknown Location
# 1143  12/29/2016 20:53  12/29/2016 21:42  Business           Kar?chi
# 1155            Totals               NaN       NaN               NaN
#
#                     STOP*   MILES* PURPOSE*
# 1             Fort Pierce      5.0      NaN
# 32    Lake Wellingborough      7.2      NaN
# ...

# %%
null_rows=Uber_data[Uber_data['START_DATE*'].isnull()]
print(null_rows)
# Out:
# Empty DataFrame
# Columns: [START_DATE*, END_DATE*, CATEGORY*, START*, STOP*, MILES*, PURPOSE*]
# Index: []

# %%
Uber_data = Uber_data.rename(columns={'START_DATE*': 'START_DATE','END_DATE*': 'END_DATE','START*': 'START'})
Uber_data
# Out:
#             START_DATE          END_DATE CATEGORY*             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
Uber_data.head()
# Out:
#        START_DATE        END_DATE CATEGORY*        START            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
Uber_data.tail()
# Out:
#             START_DATE          END_DATE CATEGORY*             START  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
Uber_data.iloc[0] #first_row data and access specific row
# Out:
# START_DATE    1/1/2016 21:11
# END_DATE      1/1/2016 21:17
# CATEGORY*           Business
# START            Fort Pierce
# STOP*            Fort Pierce
# MILES*                   5.1
# PURPOSE*      Meal/Entertain
# Name: 0, dtype: object

# %%
Uber_data.iloc[2:8] #row 2-7
# Out:
#       START_DATE*       END_DATE* CATEGORY*           START*            STOP*  \
# 2  1/2/2016 20:25  1/2/2016 20:38  Business      Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business      Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business      Fort Pierce  West Palm Beach
# 5  1/6/2016 17:15  1/6/2016 17:19  Business  West Palm Beach  West Palm Beach
# 6  1/6/2016 17:30  1/6/2016 17:35  Business  West Palm Beach       Palm Beach
# 7  1/7/2016 13:27  1/7/2016 13:33  Business             Cary             Cary
#
#    MILES*         PURPOSE*
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit
# 5     4.3   Meal/Entertain
# 6     7.1          Meeting
# 7     0.8          Meeting

# %%
Uber_data.iloc[2:8,1:5] #row 2-7 col-1-4

# %%
Uber_data['START_DATE']

# %%
import pandas as pd
Uber_data=pd.read_csv("Uber_Drives_2016.csv")

# %%
Uber_data[['START_DATE*','STOP*','PURPOSE*']]
# Out:
#            START_DATE*             STOP*         PURPOSE*
# 0       1/1/2016 21:11       Fort Pierce   Meal/Entertain
# 1        1/2/2016 1:25       Fort Pierce              NaN
# 2       1/2/2016 20:25       Fort Pierce  Errand/Supplies
# 3       1/5/2016 17:31       Fort Pierce          Meeting
# 4       1/6/2016 14:42   West Palm Beach   Customer Visit
# ...                ...               ...              ...
# 1151  12/31/2016 13:24  Unknown Location   Temporary Site
# 1152  12/31/2016 15:03  Unknown Location          Meeting
# 1153  12/31/2016 21:32           Gampaha   Temporary Site
# 1154  12/31/2016 22:08         Ilukwatta   Temporary Site
# 1155            Totals               NaN              NaN
#
# [1156 rows x 3 columns]

# %%
Uber_data.loc[[1,2,3],['START*','STOP*','MILES*']]
# Out:
#         START*        STOP*  MILES*
# 1  Fort Pierce  Fort Pierce     5.0
# 2  Fort Pierce  Fort Pierce     4.8
# 3  Fort Pierce  Fort Pierce     4.7

# %%
temp=pd.DataFrame({'A':[1],'B':[5],'c':['2025-1-19']})
temp
# Out:
#    A  B          c
# 0  1  5  2025-1-19

# %%
temp.dtypes
# Out:
# A     int64
# B     int64
# c    object
# dtype: object

# %%
temp['c']=pd.to_datetime(temp['c'])
temp.dtypes
# Out:
# A             int64
# B             int64
# c    datetime64[ns]
# dtype: object

# %%
Uber_data[['START_DATE*','END_DATE*']]=pd.to_datetime(Uber_data[['START_DATE*','END_DATE*']])	
Uber_date.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 Uber_data[['START_DATE*','END_DATE*']]=pd.to_datetime(Uber_data[['START_DATE*','END_DATE*']])
#       2 Uber_date.dtypes
#
# File E:\anaconda\new\Lib\site-packages\pandas\core\tools\datetimes.py:1070, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1070     result = _assemble_from_unit_mappings(arg, errors, utc)
#    1071 elif isinstance(arg, Index):
#    1072     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# File E:\anaconda\new\Lib\site-packages\pandas\core\tools\datetimes.py:1186, in _assemble_from_unit_mappings(arg, errors, utc)
#    1184 if len(req):
# ...

# %%
temp['A']=temp['A'].astype(str)
temp.dtypes
# Out:
# A            object
# B             int64
# c    datetime64[ns]
# dtype: object

# %%
temp1=temp
temp1['c'] = pd.to_datetime(temp1['c'], format="%d-%m-%y")
temp1.dtypes
# Out:
# A            object
# B             int64
# c    datetime64[ns]
# dtype: object

# %%
#1.Boolean indexing and filtering
a=[Uber_data['MILES*']>6]
a
# Out:
# [0       False
#  1       False
#  2       False
#  3       False
#  4        True
#          ...
#  1151    False
#  1152     True
#  1153     True
#  1154     True
#  1155     True
#  Name: MILES*, Length: 1156, dtype: bool]

# %%
a=Uber_data[(Uber_data['MILES*']>6)&(Uber_data['MILES*']<8)]
a
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 6       1/6/2016 17:30    1/6/2016 17:35  Business   West Palm Beach
# 11     1/10/2016 18:18   1/10/2016 18:53  Business          Elmhurst
# 12     1/10/2016 19:12   1/10/2016 19:32  Business           Midtown
# 13      1/11/2016 8:55    1/11/2016 9:21  Business       East Harlem
# 32      1/19/2016 9:09    1/19/2016 9:23  Business       Whitebridge
# ...                ...               ...       ...               ...
# 1123  12/27/2016 16:34  12/27/2016 16:58  Business  Unknown Location
# 1138  12/29/2016 14:42  12/29/2016 14:58  Business           Kar?chi
# 1142  12/29/2016 20:15  12/29/2016 20:45  Business           Kar?chi
# 1143  12/29/2016 20:53  12/29/2016 21:42  Business           Kar?chi
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
#
#                     STOP*  MILES*         PURPOSE*
# 6              Palm Beach     7.1          Meeting
# ...

# %%
df3=Uber_data.loc[Uber_data['START*']=="New York"]
df3
# Out:
#          START_DATE*        END_DATE* CATEGORY*    START*             STOP*  \
# 10   1/10/2016 15:08  1/10/2016 15:51  Business  New York            Queens
# 22   1/12/2016 16:02  1/12/2016 17:00  Business  New York     Queens County
# 106  2/14/2016 16:35  2/14/2016 17:02  Business  New York  Long Island City
# 423  6/10/2016 15:19  6/10/2016 16:28  Business  New York           Jamaica
#
#      MILES* PURPOSE*
# 10     10.8  Meeting
# 22     15.1  Meeting
# 106    13.0  Meeting
# 423    16.3  Meeting

# %%
Uber_data.loc[Uber_data['START*'].isin(['New york','Cary'])]
# Out:
#            START_DATE*         END_DATE* CATEGORY* START*        STOP*  \
# 7       1/7/2016 13:27    1/7/2016 13:33  Business   Cary         Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business   Cary  Morrisville
# 28     1/15/2016 11:43   1/15/2016 12:03  Business   Cary       Durham
# 30     1/18/2016 14:55   1/18/2016 15:06  Business   Cary         Cary
# 34     1/20/2016 10:36   1/20/2016 11:11  Business   Cary      Raleigh
# ...                ...               ...       ...    ...          ...
# 1049  12/13/2016 20:20  12/13/2016 20:29  Business   Cary         Cary
# 1050  12/14/2016 16:52  12/14/2016 17:10  Business   Cary         Cary
# 1051  12/14/2016 17:22  12/14/2016 17:34  Business   Cary         Cary
# 1052  12/14/2016 17:50  12/14/2016 18:00  Business   Cary  Morrisville
# 1054  12/15/2016 14:20  12/15/2016 14:54  Business   Cary  Morrisville
#
#       MILES*        PURPOSE*
# 7        0.8         Meeting
# 8        8.3         Meeting
# ...

# %%
def1=Uber_dataloc[(Uber_data['MILES*']>10)&(Uber_data['START*'].isin([Cary','Morris'])]
# Out:
#   Cell In[8], line 1
#     def1=Uber_dataloc[(Uber_data['MILES*']>10)&(Uber_data['START*'].isin([Cary','Morris'])]
#                                                                                        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
import numpy as np
Uber_data['MILE_CAT'] = np.where(Uber_data['MILES*'] > 100, "Long trip", "Short trip")
Uber_data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*    MILE_CAT
# 0     5.1   Meal/Entertain  Short trip
# 1     5.0              NaN  Short trip
# 2     4.8  Errand/Supplies  Short trip
# 3     4.7          Meeting  Short trip
# 4    63.7   Customer Visit  Short trip

# %%
conditions=[(Uber_data['MILES*']>100),(Uber_data['MILES*']>50) & (Uber_data['MILES*']<=100),(Uber_data['MILES*']<=50)]
categories=["long trip","medium trip","short trip"]
Uber_data["MILE_CART"]=np.select(conditions, categories,default="unkown")
Uber_data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*    MILE_CAT    MILE_CART
# ...
