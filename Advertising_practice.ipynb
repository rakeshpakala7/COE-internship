# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 
import numpy as np
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
#load the data set
df=pd.read_csv("Advertising.csv")
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]>

# %%
df.head(5)
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.tail(5)
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.sample
# Out:
# <bound method NDFrame.sample of      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]>

# %%
#finging the missing values
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %% [markdown]
# # seaborn plots

# %%
#description of nummerical data of histogram
sns.histplot(x=df['TV'])
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(x=df['TV'],kde='true')
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(x=df['TV'],kde='true',bins=40)
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(x=df['Radio'])
# Out:
# <Axes: xlabel='Radio', ylabel='Count'>

# %%
sns.histplot(x=df['Radio'],kde='true')
# Out:
# <Axes: xlabel='Radio', ylabel='Count'>

# %%
sns.histplot(x=df['Radio'],kde='true',bins=40)
# Out:
# <Axes: xlabel='Radio', ylabel='Count'>

# %%
sns.histplot(x=df['Newspaper'])
# Out:
# <Axes: xlabel='Newspaper', ylabel='Count'>

# %%
sns.histplot(x=df['Newspaper'],kde='true')
# Out:
# <Axes: xlabel='Newspaper', ylabel='Count'>

# %%
sns.histplot(x=df['Newspaper'],kde='true',bins=40)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Count'>

# %%
sns.histplot(x=df['Sales'])
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
sns.histplot(x=df['Sales'],kde='true')
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
sns.histplot(x=df['Sales'],kde='true',bins=40)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %% [markdown]
# # insights

# %%
#considering -0.5 to +0.5 this range can be normal
#tv,Unnammed: 0,Radio,Sales this 4 colums are normal skew
#only one column i.e Newspaper is not normal skew

# %%
df['TV'].skew()
# Out:
# np.float64(-0.06985336213274573)

# %%
df['Unnamed: 0'].skew()
# Out:
# np.float64(0.0)

# %%
df['Radio'].skew()
# Out:
# np.float64(0.0)

# %%
df['Newspaper'].skew()
# Out:
# np.float64(0.8947204074986175)

# %%
df['Sales'].skew()
# Out:
# np.float64(0.4075714250767127)

# %% [markdown]
# # scatterplot graphs

# %%
sns.scatterplot(x=df['Sales'],y=df['Unnamed: 0'])
# Out:
# <Axes: xlabel='Sales', ylabel='Unnamed: 0'>

# %%
sns.scatterplot(x=df['Sales'],y=df['TV'])
# Out:
# <Axes: xlabel='Sales', ylabel='TV'>

# %%
sns.scatterplot(x=df['Sales'],y=df['Radio'])
# Out:
# <Axes: xlabel='Sales', ylabel='Radio'>

# %%
sns.scatterplot(x=df['Sales'],y=df['Newspaper'])
# Out:
# <Axes: xlabel='Sales', ylabel='Newspaper'>

# %%
# unnamed: 0 -> sales is random
# tv -> sales is positive
# Radio -> sales is positive
# newspare -> sales is random

# %%
df.corr()
# Out:
#             Unnamed: 0        TV     Radio  Newspaper     Sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# Radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# Newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# Sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %% [raw]
# -->we are consider -1 to +1
# 0 to 0.25 is weak positive
# 0.25 to 0.60 is moderate positive
# more 0.60 is strong positive
#
# Unnamed: 0	-> sales is weak negative
# TV -> sales is strong Positive
# Radio -> sales is moderate positive
# Newspaper -> sales is weak positive

# %%
#we can know which is weak and strong
sns.heatmap(df.corr(),annot=True,cmap='Reds')
plt.show()

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df.drop('Unnamed: 0',axis=1,inplace=True)
#
# File E:\anaconda\new\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
x=df[['TV']]
y=df.Sales

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_predict=lr.predict(x_test)

# %%
from sklearn.metrics import (r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error)
r2score = r2_score(y_test,y_predict)
r2score
# Out:
# 0.46138746336817515

# %%
print("MSE : ",mean_squared_error(y_test,y_predict))
print("MAE : ",mean_absolute_error(y_test,y_predict))
print("RMSE : ",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE :  13.06226628830567
# MAE :  2.990565035759226
# RMSE :  3.6141757412037494

# %%
x=df[['Radio']]
y=df.Sales

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_predict=lr.predict(x_test)

# %%
from sklearn.metrics import (r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error)
r2score = r2_score(y_test,y_predict)
r2score
# Out:
# 0.37864501183785726

# %%
print("MSE : ",mean_squared_error(y_test,y_predict))
print("MAE : ",mean_absolute_error(y_test,y_predict))
print("RMSE : ",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE :  15.068910882943161
# MAE :  3.268917036469783
# RMSE :  3.881869508747449

# %%
x=df[['Newspaper']]
y=df.Sales

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_predict=lr.predict(x_test)

# %%
from sklearn.metrics import (r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error)
r2score = r2_score(y_test,y_predict)
r2score
# Out:
# -0.11728796161004906

# %%
print("MSE : ",mean_squared_error(y_test,y_predict))
print("MAE : ",mean_absolute_error(y_test,y_predict))
print("RMSE : ",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE :  27.096125475528662
# MAE :  3.992290912504232
# RMSE :  5.205393882841976
